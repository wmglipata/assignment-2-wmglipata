# %%
# %%writefile asgmnt2_pdc_lipatawilmar.py
from mpi4py import MPI

# Initialize MPI environment
comm = MPI.COMM_WORLD
rank = comm.Get_rank()
size = comm.Get_size()

if rank == 0:
    # MASTER PROCESS
    print(f"Master process (Rank {rank}) started. Total processes: {size}\n")

    for i in range(1, size):
        # Master receives data from each worker
        result = comm.recv(source=i)
        print(f"Received from Worker {result['rank']}:")
        print(f"  - Task assigned: {result['task']}")
        print(f"  - Calculated Sum: {result['sum']}")
        print("-" * 30)
else:
    # WORKER PROCESSES
    # 1. Assign a unique task name
    task_name = f"Data Chunk {rank}"

    # 2. Perform a simple computation (summing a range of numbers)
    # Each worker gets a different range based on its rank
    start_num = rank * 10
    end_num = start_num + 10
    total_sum = sum(range(start_num, end_num))

    # 3. Pack data into a message and send it to the Master (dest=0)
    message = {
        "rank": rank,
        "task": task_name,
        "sum": total_sum
    }
    comm.send(message, dest=0)
# Out:
# Writing asgmnt2_pdc_lipatawilmar.py

# %%
# Run the MPI script with 4 processes
! "C:\Program Files\Microsoft MPI\Bin\mpiexec.exe" -n 4 python asgmnt2_pdc_lipatawilmar.py
# Out:
# /bin/bash: line 1: C:\Program Files\Microsoft MPI\Bin\mpiexec.exe: command not found

# %%
# Install OpenMPI if not already installed (common for Linux environments like Colab)
# !apt-get update -qq > /dev/null
# !apt-get install -y openmpi-bin > /dev/null

# Install mpi4py Python library
# !pip install mpi4py

# Run the MPI script with 4 processes using mpirun, allowing root execution and oversubscribing
# !mpirun --allow-run-as-root --oversubscribe -n 4 python asgmnt2_pdc_lipatawilmar.py
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Collecting mpi4py
#   Downloading mpi4py-4.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (16 kB)
# Downloading mpi4py-4.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_5_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.4 MB/s eta 0:00:00
# Installing collected packages: mpi4py
# Successfully installed mpi4py-4.1.1
# Master process started
#
# Received from process 1 | Task: Data chunk 1 | Sum: 14950
# Received from process 2 | Task: Data chunk 2 | Sum: 24950
# Received from process 3 | Task: Data chunk 3 | Sum: 34950
